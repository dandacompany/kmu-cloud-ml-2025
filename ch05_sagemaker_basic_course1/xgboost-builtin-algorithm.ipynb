# %% [markdown]
# 라이브러리 준비

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import chart_studio.plotly as py
import cufflinks as cf
cf.go_offline(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.32.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
from kaggle.api.kaggle_api_extended import KaggleApi
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)
import awswrangler as wr

# %%
import os
import sagemaker
import boto3
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# SageMaker 세션 및 역할 설정

# %%
boto3_session = boto3.Session(profile_name='awstutor')
sagemaker_session = sagemaker.Session(boto_session=boto3_session)
role = os.environ.get('SAGEMAKER_EXECUTION_ROLE_ARN')
# Out:
# INFO:botocore.credentials:Found credentials in shared credentials file: ~/.aws/credentials

# %% [markdown]
# 데이터셋 다운로드

# %%
# Kaggle API 인증
api = KaggleApi()
api.authenticate()

# 데이터셋 다운로드 경로 설정
download_path = 'dataset/bike-sharing'
os.makedirs(download_path, exist_ok=True)

# 데이터셋 다운로드
api.dataset_download_files('archit9406/bike-sharing', path=download_path, unzip=True)

print("'archit9406/bike-sharing' 데이터셋이 'dataset/bike-sharing' 폴더에 다운로드되었습니다.")
# Out:
# Dataset URL: https://www.kaggle.com/datasets/archit9406/bike-sharing
# 'archit9406/bike-sharing' 데이터셋이 'dataset/bike-sharing' 폴더에 다운로드되었습니다.

# %% [markdown]
# 데이터 로드 및 확인

# %%
df = pd.read_csv('dataset/bike-sharing/hour.csv')
df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# 시계열 인덱스 설정 및 컬럼 정리

# %%
# dteday와 hr를 결합하여 datetime 열 생성
df['datetime'] = pd.to_datetime(df['dteday']) + pd.to_timedelta(df['hr'], unit='h')

# datetime을 인덱스로 설정
df.set_index('datetime', inplace=True)
df.yr = df.index.year

# instant와 dteday 컬럼 삭제
df = df.drop(['instant', 'dteday'], axis=1)

df.head()
# Out:
#                      season    yr  mnth  hr  holiday  weekday  workingday  \
# datetime
# 2011-01-01 00:00:00       1  2011     1   0        0        6           0
# 2011-01-01 01:00:00       1  2011     1   1        0        6           0
# 2011-01-01 02:00:00       1  2011     1   2        0        6           0
# 2011-01-01 03:00:00       1  2011     1   3        0        6           0
# 2011-01-01 04:00:00       1  2011     1   4        0        6           0
#
#                      weathersit  temp   atemp   hum  windspeed  casual  \
# datetime
# 2011-01-01 00:00:00           1  0.24  0.2879  0.81        0.0       3
# 2011-01-01 01:00:00           1  0.22  0.2727  0.80        0.0       8
# 2011-01-01 02:00:00           1  0.22  0.2727  0.80        0.0       5
# 2011-01-01 03:00:00           1  0.24  0.2879  0.75        0.0       3
# 2011-01-01 04:00:00           1  0.24  0.2879  0.75        0.0       0
#
#                      registered  cnt
# datetime
# 2011-01-01 00:00:00          13   16
# 2011-01-01 01:00:00          32   40
# 2011-01-01 02:00:00          27   32
# 2011-01-01 03:00:00          10   13
# 2011-01-01 04:00:00           1    1

# %% [markdown]
# 레이블 컬럼 첫열로 이동

# %%
# cnt 컬럼을 맨 처음으로 이동
columns = ['cnt'] + [col for col in df.columns if col != 'cnt']
df = df[columns]

df.head()
# Out:
#                      cnt  season    yr  mnth  hr  holiday  weekday  \
# datetime
# 2011-01-01 00:00:00   16       1  2011     1   0        0        6
# 2011-01-01 01:00:00   40       1  2011     1   1        0        6
# 2011-01-01 02:00:00   32       1  2011     1   2        0        6
# 2011-01-01 03:00:00   13       1  2011     1   3        0        6
# 2011-01-01 04:00:00    1       1  2011     1   4        0        6
#
#                      workingday  weathersit  temp   atemp   hum  windspeed  \
# datetime
# 2011-01-01 00:00:00           0           1  0.24  0.2879  0.81        0.0
# 2011-01-01 01:00:00           0           1  0.22  0.2727  0.80        0.0
# 2011-01-01 02:00:00           0           1  0.22  0.2727  0.80        0.0
# 2011-01-01 03:00:00           0           1  0.24  0.2879  0.75        0.0
# 2011-01-01 04:00:00           0           1  0.24  0.2879  0.75        0.0
#
#                      casual  registered
# datetime
# 2011-01-01 00:00:00       3          13
# 2011-01-01 01:00:00       8          32
# 2011-01-01 02:00:00       5          27
# 2011-01-01 03:00:00       3          10
# 2011-01-01 04:00:00       0           1

# %% [markdown]
# 데이터 분리 (훈련 / 검증 / 테스트)

# %%
# 데이터를 train, validation, test로 분리
train_size = int(len(df) * 0.7)
val_size = int(len(df) * 0.15)

train_df = df[:train_size]
val_df = df[train_size:train_size+val_size]
test_df = df[train_size+val_size:]

print(f"훈련 데이터 크기: {train_df.shape}")
print(f"검증 데이터 크기: {val_df.shape}")
print(f"테스트 데이터 크기: {test_df.shape}")
# Out:
# 훈련 데이터 크기: (12165, 15)
# 검증 데이터 크기: (2606, 15)
# 테스트 데이터 크기: (2608, 15)

# %% [markdown]
# S3에 데이터 업로드

# %%
bucket_name = 'dante-sagemaker'
project_name = 'bike-sharing'

# %%
input_path = f's3://{bucket_name}/{project_name}/input'
output_path = f's3://{bucket_name}/{project_name}/output'
model_path = f's3://{bucket_name}/{project_name}/model'
script_path = f's3://{bucket_name}/{project_name}/script'
train_path = f'{input_path}/train/train.csv'
val_path = f'{input_path}/val/val.csv'
test_path = f'{input_path}/test/test.csv'

# %%
wr.s3.to_csv(train_df, train_path, index=False, header=False, boto3_session=boto3_session)
wr.s3.to_csv(val_df, val_path, index=False, header=False, boto3_session=boto3_session)
wr.s3.to_csv(test_df, test_path, index=False, header=False, boto3_session=boto3_session)
# Out:
# {'paths': ['s3://dante-sagemaker/bike-sharing/input/test.csv'],
#  'partitions_values': {}}

# %% [markdown]
# 빌트인 모델 및 하이퍼파라미터 설정

# %%
container = sagemaker.image_uris.retrieve("xgboost",sagemaker_session.boto_region_name,version="1.7-1")
use_spot_instances = True
max_wait = 3600
max_run = 3600
instance_type = 'ml.m5.xlarge'

# %%
container
# Out:
# '366743142698.dkr.ecr.ap-northeast-2.amazonaws.com/sagemaker-xgboost:1.7-1'

# %%
estimator = sagemaker.estimator.Estimator(
    image_uri=container,  # 사용할 Docker 이미지의 URI
    role=role,  # IAM 역할 ARN
    sagemaker_session=sagemaker_session,  # SageMaker 세션 객체
    instance_count=1,  # 사용할 인스턴스 수
    instance_type=instance_type,  # 사용할 인스턴스 유형
    max_run=max_run,  # 최대 실행 시간 (초)
    use_spot_instances=use_spot_instances,  # 스팟 인스턴스 사용 여부
    max_wait=max_wait,  # 스팟 인스턴스 대기 최대 시간 (초)
    output_path=output_path,  # 모델 아티팩트 저장 경로
    base_job_name=project_name,  # 훈련 작업 이름의 기본 접두사
)

# %%
estimator.set_hyperparameters(max_depth=5,
                              objective="reg:squarederror",
                              eta=0.1,
                              num_round=150)

# %% [markdown]
# 데이터 경로 지정 및 모델 훈련

# %%
training_input_config = sagemaker.session.TrainingInput(
    s3_data=train_path,
    content_type='csv',
    s3_data_type='S3Prefix')

validation_input_config = sagemaker.session.TrainingInput(
    s3_data=val_path,
    content_type='csv',
    s3_data_type='S3Prefix'
)

data_channels = {'train': training_input_config, 'validation': validation_input_config}
estimator.fit(data_channels)
# Out:
# INFO:sagemaker:Creating training-job with name: bike-sharing-2024-07-30-02-29-36-160
# 2024-07-30 02:29:36 Starting - Starting the training job...
# 2024-07-30 02:29:52 Starting - Preparing the instances for training...
# 2024-07-30 02:30:28 Downloading - Downloading the training image.........
# 2024-07-30 02:32:00 Training - Training image download completed. Training in progress..[2024-07-30 02:32:07.500 ip-10-0-145-135.ap-northeast-2.compute.internal:7 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2024-07-30:02:32:07:INFO] Imported framework sagemaker_xgboost_container.training
# [2024-07-30:02:32:07:INFO] Failed to parse hyperparameter objective value reg:squarederror to Json.
# Returning the value itself
# [2024-07-30:02:32:07:INFO] No GPUs detected (normal if no gpus installed)
# [2024-07-30:02:32:07:INFO] Running XGBoost Sagemaker in algorithm mode
# [2024-07-30:02:32:07:INFO] Determined delimiter of CSV input is ','
# [2024-07-30:02:32:07:INFO] Determined delimiter of CSV input is ','
# [2024-07-30:02:32:07:INFO] Determined delimiter of CSV input is ','
# [2024-07-30:02:32:07:INFO] Determined delimiter of CSV input is ','
# [2024-07-30:02:32:07:INFO] Single node training.
# [2024-07-30:02:32:07:INFO] Train matrix has 12165 rows and 14 columns
# [2024-07-30:02:32:07:INFO] Validation matrix has 2606 rows
# [2024-07-30 02:32:07.584 ip-10-0-145-135.ap-northeast-2.compute.internal:7 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2024-07-30 02:32:07.584 ip-10-0-145-135.ap-northeast-2.compute.internal:7 INFO hook.py:201] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2024-07-30 02:32:07.584 ip-10-0-145-135.ap-northeast-2.compute.internal:7 INFO profiler_config_parser.py:102] User has disabled profiler.
# [2024-07-30 02:32:07.585 ip-10-0-145-135.ap-northeast-2.compute.internal:7 INFO hook.py:255] Saving to /opt/ml/output/tensors
# [2024-07-30 02:32:07.585 ip-10-0-145-135.ap-northeast-2.compute.internal:7 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2024-07-30:02:32:07:INFO] Debug hook created from config
# [0]#011train-rmse:198.89912#011validation-rmse:324.34836
# [2024-07-30 02:32:07.594 ip-10-0-145-135.ap-northeast-2.compute.internal:7 INFO hook.py:423] Monitoring the collections: metrics
# [2024-07-30 02:32:07.596 ip-10-0-145-135.ap-northeast-2.compute.internal:7 INFO hook.py:486] Hook is writing from the hook with pid: 7
# [1]#011train-rmse:179.30640#011validation-rmse:293.38269
# [2]#011train-rmse:161.63483#011validation-rmse:265.68890
# [3]#011train-rmse:145.73967#011validation-rmse:240.35245
# [4]#011train-rmse:131.41328#011validation-rmse:217.88605
# [5]#011train-rmse:118.49898#011validation-rmse:197.42517
# [6]#011train-rmse:106.86569#011validation-rmse:179.04347
# [7]#011train-rmse:96.36131#011validation-rmse:162.54215
# [8]#011train-rmse:86.90271#011validation-rmse:147.72879
# [9]#011train-rmse:78.37059#011validation-rmse:134.01347
# [10]#011train-rmse:70.69602#011validation-rmse:121.41969
# [11]#011train-rmse:63.77706#011validation-rmse:110.60881
# [12]#011train-rmse:57.55314#011validation-rmse:101.04660
# [13]#011train-rmse:51.93041#011validation-rmse:91.78204
# [14]#011train-rmse:46.86684#011validation-rmse:83.24023
# [15]#011train-rmse:42.31132#011validation-rmse:75.60307
# [16]#011train-rmse:38.20583#011validation-rmse:69.18730
# [17]#011train-rmse:34.49839#011validation-rmse:63.39655
# [18]#011train-rmse:31.15777#011validation-rmse:57.81762
# [19]#011train-rmse:28.15621#011validation-rmse:52.83134
# [20]#011train-rmse:25.45442#011validation-rmse:48.08751
# [21]#011train-rmse:23.01035#011validation-rmse:44.31119
# [22]#011train-rmse:20.81174#011validation-rmse:40.53693
# [23]#011train-rmse:18.83456#011validation-rmse:37.05365
# [24]#011train-rmse:17.05271#011validation-rmse:34.32601
# [25]#011train-rmse:15.44860#011validation-rmse:31.42253
# [26]#011train-rmse:14.00367#011validation-rmse:28.78760
# [27]#011train-rmse:12.70231#011validation-rmse:26.50355
# [28]#011train-rmse:11.53180#011validation-rmse:24.51712
# [29]#011train-rmse:10.47891#011validation-rmse:22.77725
# [30]#011train-rmse:9.53793#011validation-rmse:21.23177
# [31]#011train-rmse:8.68770#011validation-rmse:19.79336
# [32]#011train-rmse:7.94005#011validation-rmse:18.47877
# [33]#011train-rmse:7.26137#011validation-rmse:17.25523
# [34]#011train-rmse:6.65567#011validation-rmse:16.16951
# [35]#011train-rmse:6.12026#011validation-rmse:15.32019
# [36]#011train-rmse:5.64454#011validation-rmse:14.64782
# [37]#011train-rmse:5.21371#011validation-rmse:13.91295
# [38]#011train-rmse:4.84247#011validation-rmse:13.22577
# [39]#011train-rmse:4.50488#011validation-rmse:12.60852
# [40]#011train-rmse:4.20570#011validation-rmse:12.06921
# [41]#011train-rmse:3.94173#011validation-rmse:11.60952
# [42]#011train-rmse:3.70894#011validation-rmse:11.16837
# [43]#011train-rmse:3.51000#011validation-rmse:10.74669
# [44]#011train-rmse:3.33203#011validation-rmse:10.41510
# [45]#011train-rmse:3.18078#011validation-rmse:10.09567
# [46]#011train-rmse:3.04947#011validation-rmse:9.81544
# [47]#011train-rmse:2.93052#011validation-rmse:9.59789
# [48]#011train-rmse:2.83332#011validation-rmse:9.39152
# [49]#011train-rmse:2.74344#011validation-rmse:9.18069
# [50]#011train-rmse:2.66720#011validation-rmse:8.99810
# [51]#011train-rmse:2.60607#011validation-rmse:8.83519
# [52]#011train-rmse:2.55397#011validation-rmse:8.67212
# [53]#011train-rmse:2.50415#011validation-rmse:8.58203
# [54]#011train-rmse:2.46147#011validation-rmse:8.51138
# [55]#011train-rmse:2.42372#011validation-rmse:8.38289
# [56]#011train-rmse:2.39063#011validation-rmse:8.32665
# [57]#011train-rmse:2.36181#011validation-rmse:8.21728
# [58]#011train-rmse:2.33679#011validation-rmse:8.16344
# [59]#011train-rmse:2.31172#011validation-rmse:8.11926
# [60]#011train-rmse:2.28660#011validation-rmse:8.08442
# [61]#011train-rmse:2.26913#011validation-rmse:8.01637
# [62]#011train-rmse:2.22831#011validation-rmse:7.93587
# [63]#011train-rmse:2.20931#011validation-rmse:7.90030
# [64]#011train-rmse:2.17633#011validation-rmse:7.84137
# [65]#011train-rmse:2.16082#011validation-rmse:7.75921
# [66]#011train-rmse:2.13393#011validation-rmse:7.67566
# [67]#011train-rmse:2.12221#011validation-rmse:7.61592
# [68]#011train-rmse:2.10796#011validation-rmse:7.60358
# [69]#011train-rmse:2.08829#011validation-rmse:7.56755
# [70]#011train-rmse:2.07271#011validation-rmse:7.54388
# [71]#011train-rmse:2.06341#011validation-rmse:7.47900
# [72]#011train-rmse:2.05687#011validation-rmse:7.44845
# [73]#011train-rmse:2.04624#011validation-rmse:7.42477
# [74]#011train-rmse:2.04089#011validation-rmse:7.39197
# [75]#011train-rmse:2.03314#011validation-rmse:7.36300
# [76]#011train-rmse:2.02706#011validation-rmse:7.33191
# [77]#011train-rmse:2.01941#011validation-rmse:7.30258
# [78]#011train-rmse:2.01285#011validation-rmse:7.29088
# [79]#011train-rmse:2.00718#011validation-rmse:7.26811
# [80]#011train-rmse:2.00156#011validation-rmse:7.24788
# [81]#011train-rmse:1.99512#011validation-rmse:7.22843
# [82]#011train-rmse:1.97936#011validation-rmse:7.20027
# [83]#011train-rmse:1.96613#011validation-rmse:7.18503
# [84]#011train-rmse:1.96128#011validation-rmse:7.17111
# [85]#011train-rmse:1.95685#011validation-rmse:7.15072
# [86]#011train-rmse:1.95432#011validation-rmse:7.13826
# [87]#011train-rmse:1.94564#011validation-rmse:7.11770
# [88]#011train-rmse:1.94449#011validation-rmse:7.10456
# [89]#011train-rmse:1.94203#011validation-rmse:7.08477
# [90]#011train-rmse:1.93651#011validation-rmse:7.07201
# [91]#011train-rmse:1.93566#011validation-rmse:7.06097
# [92]#011train-rmse:1.93386#011validation-rmse:7.05146
# [93]#011train-rmse:1.93281#011validation-rmse:7.04395
# [94]#011train-rmse:1.92920#011validation-rmse:7.03068
# [95]#011train-rmse:1.91772#011validation-rmse:7.01133
# [96]#011train-rmse:1.90864#011validation-rmse:6.99240
# [97]#011train-rmse:1.90810#011validation-rmse:6.97911
# [98]#011train-rmse:1.90442#011validation-rmse:6.96387
# [99]#011train-rmse:1.89946#011validation-rmse:6.96288
# [100]#011train-rmse:1.89080#011validation-rmse:6.96126
# [101]#011train-rmse:1.89025#011validation-rmse:6.95365
# [102]#011train-rmse:1.88416#011validation-rmse:6.94328
# [103]#011train-rmse:1.87739#011validation-rmse:6.93671
# [104]#011train-rmse:1.87269#011validation-rmse:6.93459
# [105]#011train-rmse:1.87025#011validation-rmse:6.92178
# [106]#011train-rmse:1.86344#011validation-rmse:6.92055
# [107]#011train-rmse:1.86143#011validation-rmse:6.92062
# [108]#011train-rmse:1.85998#011validation-rmse:6.91374
# [109]#011train-rmse:1.85535#011validation-rmse:6.91089
# [110]#011train-rmse:1.84684#011validation-rmse:6.89493
# [111]#011train-rmse:1.84421#011validation-rmse:6.87702
# [112]#011train-rmse:1.83844#011validation-rmse:6.87132
# [113]#011train-rmse:1.83480#011validation-rmse:6.87090
# [114]#011train-rmse:1.83267#011validation-rmse:6.85869
# [115]#011train-rmse:1.82685#011validation-rmse:6.85667
# [116]#011train-rmse:1.82475#011validation-rmse:6.85602
# [117]#011train-rmse:1.82292#011validation-rmse:6.85315
# [118]#011train-rmse:1.81822#011validation-rmse:6.85239
# [119]#011train-rmse:1.81154#011validation-rmse:6.84956
# [120]#011train-rmse:1.79921#011validation-rmse:6.84010
# [121]#011train-rmse:1.79782#011validation-rmse:6.84038
# [122]#011train-rmse:1.79700#011validation-rmse:6.83571
# [123]#011train-rmse:1.79537#011validation-rmse:6.83548
# [124]#011train-rmse:1.79377#011validation-rmse:6.82542
# [125]#011train-rmse:1.78949#011validation-rmse:6.82439
# [126]#011train-rmse:1.78380#011validation-rmse:6.82207
# [127]#011train-rmse:1.77518#011validation-rmse:6.81858
# [128]#011train-rmse:1.77133#011validation-rmse:6.81503
# [129]#011train-rmse:1.76998#011validation-rmse:6.81478
# [130]#011train-rmse:1.76732#011validation-rmse:6.81470
# [131]#011train-rmse:1.76592#011validation-rmse:6.81386
# [132]#011train-rmse:1.75996#011validation-rmse:6.80862
# [133]#011train-rmse:1.75724#011validation-rmse:6.80555
# [134]#011train-rmse:1.75576#011validation-rmse:6.79023
# [135]#011train-rmse:1.74990#011validation-rmse:6.78608
# [136]#011train-rmse:1.74173#011validation-rmse:6.78012
# [137]#011train-rmse:1.74064#011validation-rmse:6.77970
# [138]#011train-rmse:1.74007#011validation-rmse:6.77414
# [139]#011train-rmse:1.73444#011validation-rmse:6.77222
# [140]#011train-rmse:1.73064#011validation-rmse:6.76824
# [141]#011train-rmse:1.72600#011validation-rmse:6.76575
# [142]#011train-rmse:1.71970#011validation-rmse:6.76387
# [143]#011train-rmse:1.71657#011validation-rmse:6.75803
# [144]#011train-rmse:1.71212#011validation-rmse:6.75707
# [145]#011train-rmse:1.70551#011validation-rmse:6.74685
# [146]#011train-rmse:1.70086#011validation-rmse:6.74529
# [147]#011train-rmse:1.69628#011validation-rmse:6.73668
# [148]#011train-rmse:1.69500#011validation-rmse:6.73050
# [149]#011train-rmse:1.69276#011validation-rmse:6.72725
#
# 2024-07-30 02:32:23 Uploading - Uploading generated training model
# 2024-07-30 02:32:23 Completed - Training job completed
# Training seconds: 130
# Billable seconds: 30
# Managed Spot Training savings: 76.9%

# %% [markdown]
# 추론 엔드포인트 생성

# %%
from sagemaker.serializers import CSVSerializer
from sagemaker.deserializers import CSVDeserializer
from sagemaker.utils import name_from_base

# %%
predictor = estimator.deploy(initial_instance_count=1,
                             instance_type='ml.m5.xlarge',
                             endpoint_name = name_from_base(project_name),
                             serializer=CSVSerializer(),
                             deserializer=CSVDeserializer(),
                             )
# Out:
# INFO:sagemaker:Creating model with name: bike-sharing-2024-07-30-02-33-14-941
# INFO:sagemaker:Creating endpoint-config with name bike-sharing-2024-07-30-02-33-14-941
# INFO:sagemaker:Creating endpoint with name bike-sharing-2024-07-30-02-33-14-941
# -------!

# %% [markdown]
# 테스트셋에 대한 예측 요청

# %%
y_test = test_df['cnt'].values
y_pred = predictor.predict(CSVSerializer().serialize(test_df.iloc[:, 1:].values))
y_pred = np.array(y_pred).flatten()
y_pred = list(map(float, y_pred))

# %% [markdown]
# 예측 성능 평가

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# MSE 계산
mse = mean_squared_error(y_test, y_pred)
print(f'평균 제곱 오차 (MSE): {mse:.4f}')

# RMSE 계산
rmse = np.sqrt(mse)
print(f'평균 제곱근 오차 (RMSE): {rmse:.4f}')

# MAE 계산
mae = mean_absolute_error(y_test, y_pred)
print(f'평균 절대 오차 (MAE): {mae:.4f}')

# R-squared 계산
r2 = r2_score(y_test, y_pred)
print(f'결정 계수 (R-squared): {r2:.4f}')
# Out:
# 평균 제곱 오차 (MSE): 103.5098
# 평균 제곱근 오차 (RMSE): 10.1740
# 평균 절대 오차 (MAE): 3.2897
# 결정 계수 (R-squared): 0.9978

# %% [markdown]
# 예측 성능 시각화

# %%
# 산점도 생성
scatter = go.Scatter(x=y_test, y=y_pred, mode='markers', marker=dict(opacity=0.5), name='데이터')

# 예측 일치선 생성
diagonal = go.Scatter(x=[y_test.min(), y_test.max()], y=[y_test.min(), y_test.max()], 
                      mode='lines', line=dict(color='red', dash='dash'), name='예측 일치선')

# 레이아웃 설정
layout = go.Layout(
    title='실제값 vs 예측값',
    xaxis=dict(title='실제값'),
    yaxis=dict(title='예측값'),
    width=800,
    height=600
)

# 그래프 생성 및 표시
fig = go.Figure(data=[scatter, diagonal], layout=layout)
fig.show()
# Out:
# <div>                            <div id="d2d6921c-af84-46b4-88f6-9c7c6a7ad962" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d2d6921c-af84-46b4-88f6-9c7c6a7ad962")) {                    Plotly.newPlot(                        "d2d6921c-af84-46b4-88f6-9c7c6a7ad962",                        [{"marker":{"opacity":0.5},"mode":"markers","name":"\ub370\uc774\ud130","x":[509,925,977,635,470,306,212,127,57,28,9,11,6,57,195,571,758,338,212,254,297,283,274,352,491,884,852,674,463,317,251,170,87,41,30,14,12,41,152,454,766,347,246,280,409,408,371,367,563,894,808,579,404,312,229,195,207,109,93,37,6,16,33,73,212,342,442,627,706,704,715,654,783,729,614,478,330,296,279,229,151,117,89,48,8,13,35,71,128,296,490,559,656,694,635,557,596,570,481,403,324,191,127,94,45,21,13,7,11,45,164,492,683,299,202,252,295,343,332,338,453,842,774,486,340,233,129,70,13,5,4,6,7,48,167,356,672,293,160,151,88,114,143,36,141,338,281,324,290,207,151,78,26,12,3,5,10,56,172,545,797,362,192,247,313,289,286,311,466,886,892,611,409,349,229,123,58,18,11,6,6,56,170,534,790,355,190,243,290,336,298,291,457,976,900,603,417,274,287,154,66,49,14,12,10,49,165,503,757,383,225,321,389,421,412,423,567,846,805,588,369,312,295,186,172,124,83,45,15,17,41,77,218,377,474,626,688,707,654,750,680,646,598,407,325,261,239,171,180,142,95,54,10,6,16,57,175,276,489,570,776,702,666,640,691,723,540,413,252,196,138,100,64,18,8,5,8,37,168,530,750,328,198,238,342,328,303,300,516,898,853,590,432,256,172,94,64,13,14,5,9,47,194,556,805,409,170,218,302,305,293,303,495,967,822,539,425,297,188,98,40,29,17,10,14,36,182,532,838,334,185,227,316,340,277,300,468,953,884,627,434,360,215,115,65,21,16,7,8,66,169,558,794,335,208,294,335,326,258,296,472,905,899,559,457,253,47,45,17,13,10,7,12,38,138,394,705,426,245,361,380,410,399,392,502,808,667,508,336,237,220,190,149,101,92,29,14,15,37,73,211,332,472,663,682,686,750,727,722,712,594,470,315,292,221,196,147,116,92,58,7,10,22,57,144,285,479,591,680,594,612,649,648,575,401,257,194,123,91,57,45,18,12,7,10,36,155,483,784,340,179,272,323,305,244,329,459,856,613,516,262,218,207,105,31,11,2,5,10,43,179,260,134,86,45,99,104,154,163,209,374,715,687,395,306,289,240,98,52,19,9,7,11,34,177,515,809,362,175,230,358,279,251,319,478,917,810,593,497,209,241,220,76,25,13,11,10,39,133,391,738,359,177,214,288,294,267,325,497,901,887,534,441,321,232,155,102,46,11,16,11,41,137,428,785,384,260,304,468,424,400,470,634,900,761,500,372,267,264,171,191,141,75,56,11,10,30,84,206,395,539,647,743,710,576,620,659,610,495,341,247,215,185,179,127,109,74,22,11,10,23,35,62,86,185,336,392,320,314,306,333,157,106,114,116,113,79,80,51,37,15,10,7,19,59,154,397,332,298,308,341,405,420,370,377,497,456,371,227,151,107,69,31,13,7,3,7,19,143,362,713,382,164,193,260,238,244,254,424,806,784,514,360,225,162,84,33,8,8,6,6,40,175,507,839,366,217,291,390,297,271,319,566,948,844,566,392,269,197,136,42,11,11,3,10,42,159,478,798,355,204,251,326,291,348,460,481,827,692,743,415,260,177,186,68,37,16,6,8,35,143,392,745,400,275,313,387,381,371,455,520,837,642,493,308,190,160,100,249,146,67,15,11,11,28,70,174,266,347,527,573,670,597,615,637,528,473,332,255,204,189,125,111,112,66,28,12,11,24,51,132,223,428,494,562,619,617,568,581,539,453,336,246,196,125,105,48,29,6,4,10,40,147,476,737,359,168,263,284,146,185,260,447,766,592,239,256,206,126,81,48,13,3,2,7,52,172,525,835,355,222,228,325,328,308,346,446,943,838,531,432,195,181,199,49,17,16,7,4,41,178,464,817,382,228,234,332,310,270,301,466,888,884,516,414,329,215,99,57,14,14,5,5,42,153,508,834,387,218,268,377,332,285,353,450,890,788,513,387,283,229,117,56,16,10,5,6,36,131,154,467,389,224,252,332,375,365,395,565,425,233,232,229,206,190,131,123,95,78,29,18,13,31,65,193,363,423,612,703,714,711,711,691,731,521,345,259,296,202,163,154,117,132,41 ...

# %%
predictor.delete_endpoint()
# Out:
# INFO:sagemaker:Deleting endpoint configuration with name: bike-sharing-2024-07-30-02-33-14-941
# INFO:sagemaker:Deleting endpoint with name: bike-sharing-2024-07-30-02-33-14-941
